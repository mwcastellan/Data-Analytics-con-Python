# %% [markdown]
# <a href="https://colab.research.google.com/github/mwcastellan/Data-Analytics-con-Python/blob/main/Clase1_MWC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad 1
# ## Marcelo Walter Castellan
#
# Hola, soy **Marcelo**, un estudiante apasionado por la *programación* y la tecnología.
# Me interesa aprender sobre ciencia de datos, desarrollo web y automatización.
#
# Mis intereses principales son:
# - 💻 Programación en Python
# - 📊 Análisis de datos
# - 🌐 Desarrollo web
#
# Podés aprender más sobre Python en su documentación oficial:
# https://docs.python.org/3/
#
# ![Mi imagen](https://drive.google.com/uc?id=1adTRkb-aZl01crKV4O-UOUs5mptaq7sW)
#
# > "El aprendizaje nunca agota la mente." – Leonardo da Vinci

# %% [markdown]
# # Actividad 2
# 1. Insertá un nuevo bloque de código en tu notebook de Colab.
# 2. Escribí un programa que:
# a) Pida al usuario que ingrese un número entero usando input()
# b) Convierta ese valor a entero (int())
# c) Use una estructura if/else para verificar si el número es divisible por 2
# d) Imprima un mensaje indicando si el número es par o impar
# 3. Ejecutá el bloque al menos dos veces, con un número par y uno impar.

# %%
# 1. Pedimos al usuario que ingrese un número
entrada = input("Por favor, ingresá un número entero: ")
# 2. Convertimos el valor de texto a entero
numero = int(entrada)
# 3. Estructura if/else para verificar divisibilidad
if numero % 2 == 0:
# 4. Mensaje si es par
    print(f"El número {numero} es par.")
else:
# 4. Mensaje si es impar
    print(f"El número {numero} es impar.")
# Out:
# Por favor, ingresá un número entero: 4896
# El número 4896 es par.
